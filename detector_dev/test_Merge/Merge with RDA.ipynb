# %% [markdown]
# # Import relevant simulation tools:

# %%
from utils import sim_merge_with_attack

print('Imported simulation tools.')
# Out:
# Imported simulation tools.

# %%
# Can delete this later, used for doing live development:

from importlib import reload
import utils
reload(utils)
from utils import sim_merge_with_attack

# %%
ACC_PR = 0.2
attack_PR = 0.20

RDA_params = [20.0,-0.5]

ACC_params = [1.0,1.0,3.5,8.0]

main_inflow = 1800 #veh/hr on main

ramp_inflow = 500 #veh/hr

sim_results_path = sim_merge_with_attack(ACC_PR,attack_PR,RDA_params,main_inflow,ramp_inflow,ACC_params)
# Out:
# Human inflows: 1440.0
# Benign ACC inflows: 288.0
# Attacking ACC inflows: 72.0
# /Users/vanderbilt/Desktop/General_research_tools/Anti-Flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /Users/vanderbilt/Desktop/General_research_tools/Anti-Flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /Users/vanderbilt/Desktop/General_research_tools/Anti-Flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /Users/vanderbilt/Desktop/General_research_tools/Anti-Flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# ...
